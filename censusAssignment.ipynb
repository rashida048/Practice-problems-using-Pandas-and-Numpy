# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
dict={}
for i in df.index:
    if df.loc[i]['STNAME'] not in dict:
        dict[df.loc[i]['STNAME']] = []
    dict[df.loc[i]['STNAME']].append(df.loc[i]['CENSUS2010POP'])
dict
# Out:
# {'Alabama': [4779736,
#   54571,
#   182265,
#   27457,
#   22915,
#   57322,
#   10914,
#   20947,
#   118572,
#   34215,
#   25989,
#   43643,
#   13859,
#   25833,
#   13932,
#   14972,
#   49948,
#   54428,
#   13228,
#   11539,
#   37765,
#   13906,
#   80406,
#   50251,
#   43820,
#   71109,
#   79303,
#   38319,
#   104430,
#   17241,
#   31704,
#   26790,
#   9045,
#   15760,
#   17302,
#   101547,
#   53227,
#   658466,
#   14564,
#   92709,
#   34339,
#   140247,
#   82782,
#   11299,
#   21452,
#   334811,
#   21027,
#   30776,
#   93019,
#   412992,
#   23068,
#   229363,
#   119490,
#   10591,
#   19746,
#   32899,
#   22913,
#   52947,
#   83593,
#   195085,
#   13763,
#   82291,
#   41616,
#   194656,
#   67023,
#   17581,
#   11670,
#   24484],
#  'Alaska': [710231,
#   3141,
#   5561,
#   291826,
#   17013,
#   997,
#   1826,
#   4847,
#   97581,
#   2508,
#   2150,
#   31275,
#   55400,
#   13477,
#   13592,
#   7459,
#   1631,
#   88995,
#   9492,
#   9430,
# ...

# %%
sm_dict = {}
for l in dict:
    sorted_l = sorted(dict[l], reverse=True)[:3]
    sm_dict[l] = sorted_l
sm_dict
# Out:
# {'Alabama': [4779736, 658466, 412992],
#  'Alaska': [710231, 291826, 97581],
#  'Arizona': [6392017, 3817117, 980263],
#  'Arkansas': [2915918, 382748, 221339],
#  'California': [37253956, 9818605, 3095313],
#  'Colorado': [5029196, 622263, 600158],
#  'Connecticut': [3574097, 916829, 894014],
#  'Delaware': [897934, 538479, 197145],
#  'District of Columbia': [601723, 601723],
#  'Florida': [18801310, 2496435, 1748066],
#  'Georgia': [9687653, 920581, 805321],
#  'Hawaii': [1360301, 953207, 185079],
#  'Idaho': [1567582, 392365, 188923],
#  'Illinois': [12830632, 5194675, 916924],
#  'Indiana': [6483802, 903393, 496005],
#  'Iowa': [3046355, 430640, 211226],
#  'Kansas': [2853118, 544179, 498365],
#  'Kentucky': [4339367, 741096, 295803],
#  'Louisiana': [4533372, 440171, 432552],
#  'Maine': [1328361, 281674, 197131],
#  'Maryland': [5773552, 971777, 863420],
#  'Massachusetts': [6547629, 1503085, 798552],
#  'Michigan': [9883640, 1820584, 1202362],
# ...

# %%
l_dict = {}
import numpy as np
for k in sm_dict:
    np_k = np.array(sm_dict[k])
    total = np_k.sum()
    l_dict[k] = total
l_dict
# Out:
# {'Alabama': 5851194,
#  'Alaska': 1099638,
#  'Arizona': 11189397,
#  'Arkansas': 3520005,
#  'California': 50167874,
#  'Colorado': 6251617,
#  'Connecticut': 5384940,
#  'Delaware': 1633558,
#  'District of Columbia': 1203446,
#  'Florida': 23045811,
#  'Georgia': 11413555,
#  'Hawaii': 2498587,
#  'Idaho': 2148870,
#  'Illinois': 18942231,
#  'Indiana': 7883200,
#  'Iowa': 3688221,
#  'Kansas': 3895662,
#  'Kentucky': 5376266,
#  'Louisiana': 5406095,
#  'Maine': 1807166,
#  'Maryland': 7608749,
#  'Massachusetts': 8849266,
#  'Michigan': 12906586,
#  'Minnesota': 6964990,
#  'Mississippi': 3399687,
#  'Missouri': 7662039,
#  'Montana': 1246686,
#  'Nebraska': 2628858,
#  'Nevada': 5073227,
#  'New Hampshire': 2012414,
#  'New Jersey': 10506868,
#  'New Mexico': 2930976,
#  'New York': 24113524,
#  'North Carolina': 11356104,
#  'North Dakota': 903677,
#  'Ohio': 13980040,
#  'Oklahoma': 5073387,
#  'Oregon': 5096118,
#  'Pennsylvania': 15451733,
#  'Rhode Island': 1845392,
# ...

# %%
result = sorted(l_dict, key = lambda key:l_dict[key], reverse=True)[:3]
result
# Out:
# ['California', 'Texas', 'New York']

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
columns_new = ['CTYNAME', 'POPESTIMATE2010',
       'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
       'POPESTIMATE2014', 'POPESTIMATE2015']

# %%
df = df[columns_new]
df.head()
# Out:
#           CTYNAME  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0         Alabama          4785161          4801108          4816089
# 1  Autauga County            54660            55253            55175
# 2  Baldwin County           183193           186659           190396
# 3  Barbour County            27341            27226            27159
# 4     Bibb County            22861            22733            22642
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 0          4830533          4846411          4858979
# 1            55038            55290            55347
# 2           195126           199713           203709
# 3            26973            26815            26489
# 4            22512            22549            22583

# %%
df.loc[2]['POPESTIMATE2010']
# Out:
# 183193

# %%
dict = {}
for i in df.index:
    if df.loc[i]['CTYNAME'] not in dict:
        dict[df.loc[i]['CTYNAME']] = []
        col = df.columns
        for c in col[1:]:            
            dict[df.loc[i]['CTYNAME']].append(df.loc[i][c])
dict
# Out:
# {'Alabama': [4785161, 4801108, 4816089, 4830533, 4846411, 4858979],
#  'Autauga County': [54660, 55253, 55175, 55038, 55290, 55347],
#  'Baldwin County': [183193, 186659, 190396, 195126, 199713, 203709],
#  'Barbour County': [27341, 27226, 27159, 26973, 26815, 26489],
#  'Bibb County': [22861, 22733, 22642, 22512, 22549, 22583],
#  'Blount County': [57373, 57711, 57776, 57734, 57658, 57673],
#  'Bullock County': [10887, 10629, 10606, 10628, 10829, 10696],
#  'Butler County': [20944, 20673, 20408, 20261, 20276, 20154],
#  'Calhoun County': [118437, 117768, 117286, 116575, 115993, 115620],
#  'Chambers County': [34098, 33993, 34075, 34153, 34052, 34123],
#  'Cherokee County': [25976, 26080, 26023, 26084, 25995, 25859],
#  'Chilton County': [43665, 43739, 43697, 43795, 43921, 43943],
#  'Choctaw County': [13841, 13593, 13543, 13378, 13289, 13170],
#  'Clarke County': [25767, 25570, 25144, 25116, 24847, 24675],
#  'Clay County': [13880, 13670, 13456, 13467, 13538, 13555],
# ...

# %%
import numpy as np
calc_dict={}
for d in dict:
    ar = np.array(dict[d])
    mx = ar.max()
    mn = ar.min()    
    calc_dict[d] = ar.max() - ar.min()

# %%
max(calc_dict, key=lambda key:dict[key])
# Out:
# 'California'

# %%
df.head()
# Out:
#           CTYNAME  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0         Alabama          4785161          4801108          4816089
# 1  Autauga County            54660            55253            55175
# 2  Baldwin County           183193           186659           190396
# 3  Barbour County            27341            27226            27159
# 4     Bibb County            22861            22733            22642
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 0          4830533          4846411          4858979
# 1            55038            55290            55347
# 2           195126           199713           203709
# 3            26973            26815            26489
# 4            22512            22549            22583

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
new_col=['REGION', 'STNAME', 'CTYNAME', 'POPESTIMATE2015', 'POPESTIMATE2014']

# %%
df1 = df[new_col]
df1.head()
# Out:
#    REGION   STNAME         CTYNAME  POPESTIMATE2015  POPESTIMATE2014
# 0       3  Alabama         Alabama          4858979          4846411
# 1       3  Alabama  Autauga County            55347            55290
# 2       3  Alabama  Baldwin County           203709           199713
# 3       3  Alabama  Barbour County            26489            26815
# 4       3  Alabama     Bibb County            22583            22549

# %%
df1['CTYNAME'].head()
# Out:
# 0    Washington
# 1    Washington
# 2    Washington
# 3    Washington
# 4    Washington
# Name: CTYNAME, dtype: object

# %%
df1.loc[df1['REGION'] == 1].head()
# Out:
#      REGION       STNAME            CTYNAME  POPESTIMATE2015  POPESTIMATE2014
# 314       1  Connecticut        Connecticut          3590886          3594762
# 315       1  Connecticut   Fairfield County           948053           945816
# 316       1  Connecticut    Hartford County           895841           896871
# 317       1  Connecticut  Litchfield County           183603           184910
# 318       1  Connecticut   Middlesex County           164063           164757

# %%
df1.loc[df1['REGION'] == 2].head()
# Out:
#      REGION    STNAME           CTYNAME  POPESTIMATE2015  POPESTIMATE2014
# 608       2  Illinois          Illinois         12859995         12882189
# 609       2  Illinois      Adams County            67013            67018
# 610       2  Illinois  Alexander County             6780             7098
# 611       2  Illinois       Bond County            16950            17124
# 612       2  Illinois      Boone County            53585            53793

# %%
df1[df1['CTYNAME'].str.startswith('Washington')]
# Out:
#       REGION          STNAME            CTYNAME  POPESTIMATE2015  \
# 0          3         Alabama         Washington          4858979
# 1          3         Alabama         Washington            55347
# 2          3         Alabama         Washington           203709
# 3          3         Alabama         Washington            26489
# 4          3         Alabama         Washington            22583
# 5          3         Alabama         Washington            57673
# 6          3         Alabama         Washington            10696
# 7          3         Alabama         Washington            20154
# 8          3         Alabama         Washington           115620
# 9          3         Alabama         Washington            34123
# 65         3         Alabama  Washington County            16804
# 186        3        Arkansas  Washington County           225477
# 311        4        Colorado  Washington County             4864
# ...

# %%
df2 = df1[(df1['CTYNAME'].str.startswith('Washington')) & (df1['POPESTIMATE2015'] > df1['POPESTIMATE2014']) 
    & (df1['REGION'] < 3)]
df2
# Out:
#       REGION        STNAME            CTYNAME  POPESTIMATE2015  \
# 896        2          Iowa  Washington County            22247
# 1419       2     Minnesota  Washington County           251597
# 2345       1  Pennsylvania  Washington County           208261
# 2355       1  Rhode Island  Washington County           126517
# 3163       2     Wisconsin  Washington County           133674
#
#       POPESTIMATE2014
# 896             22087
# 1419           249320
# 2345           208175
# 2355           126430
# 3163           133301

# %%
columns_remaining = ['STNAME', 'CTYNAME']
df3 = df2[columns_remaining]
df3
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
import numpy as np
df['AbsChange'] = ((np.array([df['POPESTIMATE2010'], df['POPESTIMATE2011'], df['POPESTIMATE2012'], df['POPESTIMATE2013'], df['POPESTIMATE2014'], df['POPESTIMATE2015']])).max())-((np.array([df['POPESTIMATE2010'], df['POPESTIMATE2011'], df['POPESTIMATE2012'], df['POPESTIMATE2013'], df['POPESTIMATE2014'], df['POPESTIMATE2015']])).min())
aclist = df['AbsChange'].tolist()
ac = np.array(aclist)
acmax = ac.max()
df.index[df['AbsChange']==acmax]
cty = df['CTYNAME']
ind1 = aclist.index(acmax)
result71 = (df['CTYNAME'].tolist())[ind1]
result71
# Out:
# 'Alabama'

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010    ...      \
# 0        4779736            4780127          4785161    ...
# 1          54571              54571            54660    ...
# 2         182265             182265           183193    ...
# 3          27457              27457            27341    ...
# 4          22915              22919            22861    ...
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# ...

# %%
state = df['STNAME'].unique()
pop = []
for st in state:
    all_pop = df.loc[df['STNAME'] == st, 'CENSUS2010POP']
    three_pop = (sorted(all_pop, reverse=True))[:3]
    pop.append(three_pop)
summary = []
for p in pop:
    summary.append(np.sum(p))
sort = sorted(summary, reverse=True)[:3]
final = []
for s in sort:
    ind = summary.index(s)
    final.append(state[ind])
final
# Out:
# ['California', 'Texas', 'New York']
