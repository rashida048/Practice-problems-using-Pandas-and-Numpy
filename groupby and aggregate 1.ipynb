# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.CENSUS2010POP.sum()
# Out:
# 617484854

# %%
df.CENSUS2010POP.max()
# Out:
# 37253956

# %%
df.CENSUS2010POP.min()
# Out:
# 82

# %%
df.CENSUS2010POP.median()
# Out:
# 26424.0

# %%
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
df = df.loc[:, 'STNAME':'POPESTIMATE2015']
df
# Out:
#          STNAME             CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# 0       Alabama             Alabama        4779736            4780127
# 1       Alabama      Autauga County          54571              54571
# 2       Alabama      Baldwin County         182265             182265
# 3       Alabama      Barbour County          27457              27457
# 4       Alabama         Bibb County          22915              22919
# 5       Alabama       Blount County          57322              57322
# 6       Alabama      Bullock County          10914              10915
# 7       Alabama       Butler County          20947              20946
# 8       Alabama      Calhoun County         118572             118586
# 9       Alabama     Chambers County          34215              34170
# 10      Alabama     Cherokee County          25989              25986
# 11      Alabama      Chilton County          43643              43631
# ...

# %%
df.groupby('STNAME').sum()
# Out:
#                       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama                     9559472            9560254          9570322
# Alaska                      1420462            1420498          1428042
# Arizona                    12784034           12784614         12816416
# Arkansas                    5831836            5831916          5844788
# California                 74507912           74509006         74668158
# Colorado                   10058392           10058648         10096508
# Connecticut                 7148194            7148236          7159434
# Delaware                    1795868            1795872          1799582
# District of Columbia        1203446            1203534          1210252
# Florida                    37602620           37609246         37699780
# Georgia                    19375306           19377362         19426908
# Hawaii                      2720602            2720602          2727960
# ...

# %%
df.groupby('STNAME').max()
# Out:
#                                         CTYNAME  CENSUS2010POP  \
# STNAME
# Alabama                          Winston County        4779736
# Alaska                Yukon-Koyukuk Census Area         710231
# Arizona                             Yuma County        6392017
# Arkansas                            Yell County        2915918
# California                          Yuba County       37253956
# Colorado                            Yuma County        5029196
# Connecticut                      Windham County        3574097
# Delaware                          Sussex County         897934
# District of Columbia       District of Columbia         601723
# Florida                       Washington County       18801310
# Georgia                            Worth County        9687653
# Hawaii                              Maui County        1360301
# Idaho                         Washington County        1567582
# Illinois                        Woodford County       12830632
# ...

# %%
df.groupby('STNAME').min()
# Out:
#                                    CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME
# Alabama                            Alabama           9045               9045
# Alaska                              Alaska            662                662
# Arizona                      Apache County           8437               8437
# Arkansas                          Arkansas           5368               5368
# California                  Alameda County           1175               1175
# Colorado                      Adams County            699                699
# Connecticut                    Connecticut         118428             118434
# Delaware                          Delaware         162310             162349
# District of Columbia  District of Columbia         601723             601767
# Florida                     Alachua County           8365               8365
# Georgia                     Appling County           1717               1717
# ...

# %%
df.groupby('STNAME').mean()
# Out:
#                       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama                1.405805e+05       1.405920e+05     1.407400e+05
# Alaska                 4.734873e+04       4.734993e+04     4.760140e+04
# Arizona                7.990021e+05       7.990384e+05     8.010260e+05
# Arkansas               7.673468e+04       7.673574e+04     7.690511e+04
# California             1.262846e+06       1.262865e+06     1.265562e+06
# Colorado               1.547445e+05       1.547484e+05     1.553309e+05
# Connecticut            7.942438e+05       7.942484e+05     7.954927e+05
# Delaware               4.489670e+05       4.489680e+05     4.498955e+05
# District of Columbia   6.017230e+05       6.017670e+05     6.051260e+05
# Florida                5.529797e+05       5.530771e+05     5.544085e+05
# Georgia                1.210957e+05       1.211085e+05     1.214182e+05
# Hawaii                 4.534337e+05       4.534337e+05     4.546600e+05
# ...

# %%
df.groupby('STNAME').std()
# Out:
#                       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama                5.801839e+05       5.802296e+05     5.808386e+05
# Alaska                 1.371077e+05       1.371109e+05     1.378496e+05
# Arizona                1.760640e+06       1.760728e+06     1.764933e+06
# Arkansas               3.347828e+05       3.347879e+05     3.355420e+05
# California             4.969099e+06       4.969170e+06     4.979447e+06
# Colorado               6.335042e+05       6.335207e+05     6.359528e+05
# Connecticut            1.098660e+06       1.098668e+06     1.100463e+06
# Delaware               3.440786e+05       3.440770e+05     3.445535e+05
# District of Columbia   0.000000e+00       0.000000e+00     0.000000e+00
# Florida                2.289124e+06       2.289534e+06     2.295116e+06
# Georgia                7.715327e+05       7.716129e+05     7.736094e+05
# Hawaii                 5.635848e+05       5.635848e+05     5.652761e+05
# ...

# %%
df.groupby('STNAME').count()
# Out:
#                       CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME
# Alabama                    68             68                 68
# Alaska                     30             30                 30
# Arizona                    16             16                 16
# Arkansas                   76             76                 76
# California                 59             59                 59
# Colorado                   65             65                 65
# Connecticut                 9              9                  9
# Delaware                    4              4                  4
# District of Columbia        2              2                  2
# Florida                    68             68                 68
# Georgia                   160            160                160
# Hawaii                      6              6                  6
# Idaho                      45             45                 45
# ...

# %%
df.groupby('STNAME').size()
# Out:
# STNAME
# Alabama                  68
# Alaska                   30
# Arizona                  16
# Arkansas                 76
# California               59
# Colorado                 65
# Connecticut               9
# Delaware                  4
# District of Columbia      2
# Florida                  68
# Georgia                 160
# Hawaii                    6
# Idaho                    45
# Illinois                103
# Indiana                  93
# Iowa                    100
# Kansas                  106
# Kentucky                121
# Louisiana                65
# Maine                    17
# Maryland                 25
# Massachusetts            15
# Michigan                 84
# Minnesota                88
# Mississippi              83
# Missouri                116
# Montana                  57
# Nebraska                 94
# Nevada                   18
# New Hampshire            11
# New Jersey               22
# New Mexico               34
# New York                 63
# ...

# %%
df.groupby('STNAME').first()
# Out:
#                                    CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME
# Alabama                            Alabama        4779736            4780127
# Alaska                              Alaska         710231             710249
# Arizona                            Arizona        6392017            6392307
# Arkansas                          Arkansas        2915918            2915958
# California                      California       37253956           37254503
# Colorado                          Colorado        5029196            5029324
# Connecticut                    Connecticut        3574097            3574118
# Delaware                          Delaware         897934             897936
# District of Columbia  District of Columbia         601723             601767
# Florida                            Florida       18801310           18804623
# Georgia                            Georgia        9687653            9688681
# ...

# %%
df.groupby('STNAME').last()
# Out:
#                                         CTYNAME  CENSUS2010POP  \
# STNAME
# Alabama                          Winston County          24484
# Alaska                Yukon-Koyukuk Census Area           5588
# Arizona                             Yuma County         195751
# Arkansas                            Yell County          22185
# California                          Yuba County          72155
# Colorado                            Yuma County          10043
# Connecticut                      Windham County         118428
# Delaware                          Sussex County         197145
# District of Columbia       District of Columbia         601723
# Florida                       Washington County          24896
# Georgia                            Worth County          21679
# Hawaii                              Maui County         154834
# Idaho                         Washington County          10198
# Illinois                        Woodford County          38664
# ...

# %%
df.groupby('STNAME').nth(5)
# Out:
#                             CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME
# Alabama               Blount County          57322              57322
# Alaska          Bristol Bay Borough            997                997
# Arizona               Graham County          37220              37220
# Arkansas               Boone County          36903              36903
# California         Calaveras County          45578              45578
# Colorado                Baca County           3788               3788
# Connecticut        New Haven County         862477             862474
# Florida              Brevard County         543376             543378
# Georgia              Baldwin County          45720              45835
# Hawaii                  Maui County         154834             154835
# Idaho                Benewah County           9285               9285
# Illinois               Brown County           6937               6937
# ...

# %%
df.groupby('STNAME').var()
# Out:
#                       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama                3.366133e+11       3.366664e+11     3.373735e+11
# Alaska                 1.879851e+10       1.879939e+10     1.900252e+10
# Arizona                3.099855e+12       3.100163e+12     3.114989e+12
# Arkansas               1.120795e+11       1.120829e+11     1.125884e+11
# California             2.469194e+13       2.469265e+13     2.479489e+13
# Colorado               4.013276e+11       4.013484e+11     4.044359e+11
# Connecticut            1.207054e+12       1.207071e+12     1.211019e+12
# Delaware               1.183901e+11       1.183890e+11     1.187171e+11
# District of Columbia   0.000000e+00       0.000000e+00     0.000000e+00
# Florida                5.240087e+12       5.241966e+12     5.267555e+12
# Georgia                5.952627e+11       5.953865e+11     5.984715e+11
# Hawaii                 3.176278e+11       3.176278e+11     3.195370e+11
# ...

# %%
df.groupby('STNAME').sem()
# Out:
#                       CENSUS2010POP  CTYNAME  ESTIMATESBASE2010  \
# STNAME
# Alabama                70357.629114      NaN       70363.179620
# Alaska                 25032.321959      NaN       25032.907337
# Arizona               440160.094643      NaN      440181.966325
# Arkansas               38402.222344      NaN       38402.802691
# California            646921.537276      NaN      646930.809239
# Colorado               78576.526670      NaN       78578.568812
# Connecticut           366220.001796      NaN      366222.605125
# Delaware              172039.317349      NaN      172038.520258
# District of Columbia       0.000000      NaN           0.000000
# Florida               277597.004156      NaN      277646.783249
# Georgia                60995.013343      NaN       61001.356080
# Hawaii                230082.511955      NaN      230082.524667
# Idaho                  35431.474746      NaN       35433.004551
# ...

# %%
df.groupby('STNAME').skew()
# Out:
#                       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME
# Alabama                    7.869099           7.869159         7.869184
# Alaska                     4.362547           4.362549         4.361638
# Arizona                    2.766764           2.766753         2.767101
# Arkansas                   8.360170           8.360139         8.359031
# California                 6.865002           6.865008         6.865974
# Colorado                   7.356665           7.356652         7.355123
# Connecticut                2.460408           2.460397         2.459802
# Delaware                   0.845973           0.846035         0.849889
# District of Columbia            NaN                NaN              NaN
# Florida                    7.796206           7.796149         7.795501
# Georgia                   12.156328          12.156399        12.155368
# Hawaii                     1.129309           1.129308         1.128787
# ...

# %%
df.describe()
# Out:
#        CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# count   3.193000e+03       3.193000e+03     3.193000e+03     3.193000e+03
# mean    1.933871e+05       1.933969e+05     1.937657e+05     1.952514e+05
# std     1.176201e+06       1.176244e+06     1.178710e+06     1.189648e+06
# min     8.200000e+01       8.200000e+01     8.300000e+01     9.000000e+01
# 25%     1.129900e+04       1.129900e+04     1.127500e+04     1.127700e+04
# 50%     2.642400e+04       2.644600e+04     2.646700e+04     2.641700e+04
# 75%     7.140400e+04       7.149100e+04     7.172100e+04     7.238700e+04
# max     3.725396e+07       3.725450e+07     3.733408e+07     3.770003e+07
#
#        POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# count     3.193000e+03     3.193000e+03     3.193000e+03     3.193000e+03
# mean      1.967445e+05     1.982007e+05     1.997541e+05     2.013272e+05
# std       1.200508e+06     1.211123e+06     1.222669e+06     1.234218e+06
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2011'].sum()
# Out:
# STNAME
# Alabama                  9602216
# Alaska                   1445440
# Arizona                 12937464
# Arkansas                 5877076
# California              75400068
# Colorado                10238960
# Connecticut              7179518
# Delaware                 1815832
# District of Columbia     1240944
# Florida                 38211066
# Georgia                 19624560
# Hawaii                   2756454
# Idaho                    3168268
# Illinois                25723764
# Indiana                 13033690
# Iowa                     6130778
# Kansas                   5739834
# Kentucky                 8735764
# Louisiana                9150762
# Maine                    2656514
# Maryland                11688342
# Massachusetts           13223594
# Michigan                19753178
# Minnesota               10696238
# Mississippi              5955998
# Missouri                12021174
# Montana                  1995492
# Nebraska                 3684766
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2011'].describe()
# Out:
#                       count          mean           std       min        25%  \
# STNAME
# Alabama                68.0  1.412091e+05  5.827716e+05    8910.0   18871.00
# Alaska                 30.0  4.818133e+04  1.394773e+05     651.0    2737.75
# Arizona                16.0  8.085915e+05  1.782895e+06    8589.0   52019.00
# Arkansas               76.0  7.732995e+04  3.374736e+05    5286.0   12666.00
# California             59.0  1.277967e+06  5.027760e+06    1111.0   49923.50
# Colorado               65.0  1.575225e+05  6.450870e+05     697.0    5843.00
# Connecticut             9.0  7.977242e+05  1.103886e+06  118418.0  166198.00
# Delaware                4.0  4.539580e+05  3.471683e+05  165242.0  191554.25
# District of Columbia    2.0  6.204720e+05  0.000000e+00  620472.0  620472.00
# Florida                68.0  5.619274e+05  2.326972e+06    8227.0   28269.00
# Georgia               160.0  1.226535e+05  7.816499e+05    1706.0   11617.25
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2011', 'POPESTIMATE2011'].sum()
# Out:
#                       POPESTIMATE2011  POPESTIMATE2011
# STNAME
# Alabama                       9602216          9602216
# Alaska                        1445440          1445440
# Arizona                      12937464         12937464
# Arkansas                      5877076          5877076
# California                   75400068         75400068
# Colorado                     10238960         10238960
# Connecticut                   7179518          7179518
# Delaware                      1815832          1815832
# District of Columbia          1240944          1240944
# Florida                      38211066         38211066
# Georgia                      19624560         19624560
# Hawaii                        2756454          2756454
# Idaho                         3168268          3168268
# Illinois                     25723764         25723764
# Indiana                      13033690         13033690
# Iowa                          6130778          6130778
# ...

# %%
df.groupby('STNAME').aggregate([np.min, np.median, 'count'])
# Out:
#                      CENSUS2010POP                 ESTIMATESBASE2010  \
#                               amin    median count              amin
# STNAME
# Alabama                       9045   36052.0    68              9045
# Alaska                         662    7244.0    30               662
# Arizona                       8437  132883.5    16              8437
# Arkansas                      5368   19840.5    76              5368
# California                    1175  181058.0    59              1175
# Colorado                       699   15324.0    65               699
# Connecticut                 118428  274055.0     9            118434
# Delaware                    162310  367812.0     4            162349
# District of Columbia        601723  601723.0     2            601767
# Florida                       8365  118407.0    68              8365
# Georgia                       1717   22957.0   160              1717
# ...

# %%
df.groupby('STNAME').aggregate({"POPESTIMATE2011": 'min', 'POPESTIMATE2012': 'max'})
# Out:
#                       POPESTIMATE2011  POPESTIMATE2012
# STNAME
# Alabama                          8910          4816089
# Alaska                            651           731228
# Arizona                          8589          6553262
# Arkansas                         5286          2949499
# California                       1111         38056055
# Colorado                          697          5191731
# Connecticut                    118418          3593541
# Delaware                       165242           917099
# District of Columbia           620472           635342
# Florida                          8227         19352021
# Georgia                          1706          9917639
# Hawaii                             90          1392641
# Idaho                             951          1596097
# Illinois                         4282         12875167
# Indiana                          6086          6538283
# Iowa                             3996          3076636
# ...

# %%
min_max = df.groupby('STNAME').aggregate({"POPESTIMATE2011": 'min', 'POPESTIMATE2012': 'max'})
min_max.columns = ["POPESTIMATE2011(min)", "POPESTIMATE2012(max)"]
min_max.head()
# Out:
#             POPESTIMATE2011(min)  POPESTIMATE2012(max)
# STNAME
# Alabama                     8910               4816089
# Alaska                       651                731228
# Arizona                     8589               6553262
# Arkansas                    5286               2949499
# California                  1111              38056055
