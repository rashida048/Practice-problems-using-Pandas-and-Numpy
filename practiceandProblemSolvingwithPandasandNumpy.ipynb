# %%
import pandas as pd
staff_df=pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director Of HR'},
                      {'Name': 'Sally', 'Role': 'Course Liaison'},
                      {'Name': 'James', 'Role': 'Grader'}])
staff_df= staff_df.set_index('Name')
staff_df
# Out:
#                  Role
# Name
# Kelly  Director Of HR
# Sally  Course Liaison
# James          Grader

# %%
import pandas as pd
student_df=pd.DataFrame([{'Name': 'Jame', 'School': 'Business'},
                      {'Name': 'Mike', 'School': 'Law'},
                      {'Name': 'James', 'School': 'Engineering'}])
student_df= student_df.set_index('Name')
student_df
# Out:
#             School
# Name
# Jame      Business
# Mike           Law
# James  Engineering

# %%
pd.merge(staff_df, student_df, how = 'right', left_index = True, right_index = True)
# Out:
#          Role       School
# Name
# Jame      NaN     Business
# Mike      NaN          Law
# James  Grader  Engineering

# %%
staff_df = staff_df.reset_index()
staff_df
# Out:
#     Name            Role
# 0  Kelly  Director Of HR
# 1  Sally  Course Liaison
# 2  James          Grader

# %%
student_df = student_df.reset_index()
student_df
# Out:
#     Name       School
# 0   Jame     Business
# 1   Mike          Law
# 2  James  Engineering

# %%
pd.merge(staff_df, student_df, how = 'left', left_on = 'Name', right_on = 'Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director Of HR          NaN
# 1  Sally  Course Liaison          NaN
# 2  James          Grader  Engineering

# %%
staff_df=pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director Of HR', 'Location': 'State Street'},
                      {'Name': 'Sally', 'Role': 'Course Liaison', 'Location': 'Washington Ave'},
                      {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Ave'}])
staff_df= staff_df.set_index('Name')
staff_df
# Out:
#              Location            Role
# Name
# Kelly    State Street  Director Of HR
# Sally  Washington Ave  Course Liaison
# James  Washington Ave          Grader

# %%
student_df=pd.DataFrame([{'Name': 'Jame', 'School': 'Business', 'Location': '1024 Billiard Ave'},
                      {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House'},
                      {'Name': 'James', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
student_df= student_df.set_index('Name')
student_df
# Out:
#                   Location       School
# Name
# Jame     1024 Billiard Ave     Business
# Mike      Fraternity House          Law
# James  512 Wilson Crescent  Engineering

# %%
pd.merge(staff_df, student_df, how='outer', left_index = True, right_index = True)
# Out:
#            Location_x            Role           Location_y       School
# Name
# Jame              NaN             NaN    1024 Billiard Ave     Business
# James  Washington Ave          Grader  512 Wilson Crescent  Engineering
# Kelly    State Street  Director Of HR                  NaN          NaN
# Mike              NaN             NaN     Fraternity House          Law
# Sally  Washington Ave  Course Liaison                  NaN          NaN

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df = (df.where(df['SUMLEV'] == 50).dropna().set_index(['STNAME', 'CTYNAME'])
.rename(columns={'ESTIMATESBASE2010': 'Estimate Base 2010'}))

# %%
df
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})
df.apply(min_max, axis=1)
# Out:
#                                    min       max
# STNAME    CTYNAME
# Alabama   Autauga County       54660.0   55347.0
#           Baldwin County      183193.0  203709.0
#           Barbour County       26489.0   27341.0
#           Bibb County          22512.0   22861.0
#           Blount County        57373.0   57776.0
#           Bullock County       10606.0   10887.0
#           Butler County        20154.0   20944.0
#           Calhoun County      115620.0  118437.0
#           Chambers County      33993.0   34153.0
#           Cherokee County      25859.0   26084.0
#           Chilton County       43665.0   43943.0
#           Choctaw County       13170.0   13841.0
#           Clarke County        24675.0   25767.0
#           Clay County          13456.0   13880.0
#           Cleburne County      14921.0   15072.0
#           Coffee County        50177.0   51211.0
#           Colbert County       54354.0   54514.0
#           Conecuh County       12662.0   13208.0
# ...

# %%
def min_max(row):
    data = row[['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']]
    row['max']=np.max(data)
    row['min']=np.max(data)
    return row
df.apply(min_max, axis=1)
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
data = ['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']
df.apply(lambda x:np.max(x[data]), axis = 1)
# Out:
# STNAME     CTYNAME
# Alabama    Autauga County         55347.0
#            Baldwin County        203709.0
#            Barbour County         27341.0
#            Bibb County            22861.0
#            Blount County          57776.0
#            Bullock County         10887.0
#            Butler County          20944.0
#            Calhoun County        118437.0
#            Chambers County        34153.0
#            Cherokee County        26084.0
#            Chilton County         43943.0
#            Choctaw County         13841.0
#            Clarke County          25767.0
#            Clay County            13880.0
#            Cleburne County        15072.0
#            Coffee County          51211.0
#            Colbert County         54514.0
#            Conecuh County         13208.0
#            Coosa County           11758.0
#            Covington County       38060.0
#            Crenshaw County        13963.0
#            Cullman County         82005.0
# ...

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df=df[df['SUMLEV']==50]

for state in df['STNAME'].unique():
    avg=np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of '+ str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
for group, frame in df.groupby('STNAME'):
    avg=np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
df = df.set_index('STNAME')

# %%
df.head()
# Out:
#          SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# STNAME
# Alabama      50       3         6      1       1  Autauga County
# Alabama      50       3         6      1       3  Baldwin County
# Alabama      50       3         6      1       5  Barbour County
# Alabama      50       3         6      1       7     Bibb County
# Alabama      50       3         6      1       9   Blount County
#
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# Alabama          54571              54571            54660            55253
# Alabama         182265             182265           183193           186659
# Alabama          27457              27457            27341            27226
# Alabama          22915              22919            22861            22733
# Alabama          57322              57322            57373            57711
#
#             ...       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME      ...
# ...

# %%
def fun(item):
    if item[0] < 'M':
        return 0
    if item[0]< 'Q':
        return 1
    return 2
for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + 'records in group' + str(group) + ' for processing.')
# Out:
# There are 1177records in group0 for processing.
# There are 1134records in group1 for processing.
# There are 831records in group2 for processing.

# %%
df = df[df['SUMLEV'] == 50]
df.groupby('STNAME').agg({'CENSUS2010POP' :np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
print(type(df.groupby(level = 0)['POPESTIMATE2010', 'POPESTIMATE2011']))
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>
# <class 'pandas.core.groupby.groupby.SeriesGroupBy'>

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010', 'POPESTIMATE2011']
.agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011': np.sum}))
# Out:
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  1.407400e+05          9602216
# Alaska                   4.760140e+04          1445440
# Arizona                  8.010260e+05         12937464
# Arkansas                 7.690511e+04          5877076
# California               1.265562e+06         75400068
# Colorado                 1.553309e+05         10238960
# Connecticut              7.954927e+05          7179518
# Delaware                 4.498955e+05          1815832
# District of Columbia     6.051260e+05          1240944
# Florida                  5.544085e+05         38211066
# Georgia                  1.214182e+05         19624560
# Hawaii                   4.546600e+05          2756454
# Idaho                    6.982160e+04          3168268
# Illinois                 2.493446e+05         25723764
# Indiana                  1.395826e+05         13033690
# Iowa                     6.101388e+04          6130778
# ...

# %%
df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg':np.average, 'sum': np.sum})
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#                                avg       sum
# STNAME
# Alabama               1.405805e+05   9559472
# Alaska                4.734873e+04   1420462
# Arizona               7.990021e+05  12784034
# Arkansas              7.673468e+04   5831836
# California            1.262846e+06  74507912
# Colorado              1.547445e+05  10058392
# Connecticut           7.942438e+05   7148194
# Delaware              4.489670e+05   1795868
# District of Columbia  6.017230e+05   1203446
# Florida               5.529797e+05  37602620
# Georgia               1.210957e+05  19375306
# Hawaii                4.534337e+05   2720602
# Idaho                 6.967031e+04   3135164
# Illinois              2.491385e+05  25661264
# Indiana               1.394366e+05  12967604
# ...

# %%
(df.set_index('STNAME').groupby(level=0)
 ['POPESTIMATE2010', 'POPESTIMATE2011']
 .agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011': np.sum}))
# Out:
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  1.407400e+05          9602216
# Alaska                   4.760140e+04          1445440
# Arizona                  8.010260e+05         12937464
# Arkansas                 7.690511e+04          5877076
# California               1.265562e+06         75400068
# Colorado                 1.553309e+05         10238960
# Connecticut              7.954927e+05          7179518
# Delaware                 4.498955e+05          1815832
# District of Columbia     6.051260e+05          1240944
# Florida                  5.544085e+05         38211066
# Georgia                  1.214182e+05         19624560
# Hawaii                   4.546600e+05          2756454
# Idaho                    6.982160e+04          3168268
# Illinois                 2.493446e+05         25723764
# Indiana                  1.395826e+05         13033690
# Iowa                     6.101388e+04          6130778
# ...

# %%
cal=pd.read_csv('http://www.calvin.edu/~stob/data/Berkeley.csv')
cal
# Out:
#        Admit  Gender Dept  Freq
# 0   Admitted    Male    A   512
# 1   Rejected    Male    A   313
# 2   Admitted  Female    A    89
# 3   Rejected  Female    A    19
# 4   Admitted    Male    B   353
# 5   Rejected    Male    B   207
# 6   Admitted  Female    B    17
# 7   Rejected  Female    B     8
# 8   Admitted    Male    C   120
# 9   Rejected    Male    C   205
# 10  Admitted  Female    C   202
# 11  Rejected  Female    C   391
# 12  Admitted    Male    D   138
# 13  Rejected    Male    D   279
# 14  Admitted  Female    D   131
# 15  Rejected  Female    D   244
# 16  Admitted    Male    E    53
# 17  Rejected    Male    E   138
# 18  Admitted  Female    E    94
# 19  Rejected  Female    E   299
# 20  Admitted    Male    F    22
# 21  Rejected    Male    F   351
# 22  Admitted  Female    F    24
# 23  Rejected  Female    F   317

# %%
staff_df=pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'}, 
                       {'Name': 'Sally', 'Role': 'Course Liaison'},
                      {'Name': 'James', 'Role': 'Grader'}])
staff_df= staff_df.set_index('Name')
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course Liaison
# James          Grader

# %%
student_df = pd.DataFrame([{'Name': 'Jame', 'School': 'Business'}, 
                           {'Name': 'Mike', 'School': 'Law'}, 
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df= student_df.set_index('Name')
student_df
# Out:
#             School
# Name
# Jame      Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df, student_df, how="outer", left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Jame              NaN     Business
# James          Grader          NaN
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course Liaison  Engineering

# %%
pd.merge(staff_df, student_df, how="inner", left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course Liaison  Engineering

# %%
pd.merge(staff_df, student_df, how="outer", left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Jame              NaN     Business
# James          Grader          NaN
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course Liaison  Engineering

# %%
staff_df=staff_df.reset_index()

# %%
student_df=student_df.reset_index()

# %%
pd.merge(staff_df, student_df, how="left", left_on='Name', right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally  Course Liaison  Engineering
# 2  James          Grader          NaN

# %%
staff_df=pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'}, 
                       {'Name': 'Sally', 'Role': 'Course Liaison', 'Location': 'Washington Ave'},
                      {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Ave'}])
staff_df
# Out:
#          Location   Name            Role
# 0    State Street  Kelly  Director of HR
# 1  Washington Ave  Sally  Course Liaison
# 2  Washington Ave  James          Grader

# %%
student_df = pd.DataFrame([{'Name': 'Jame', 'School': 'Business', 'Location': '1024 Billiard Ave'},              
                            {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'}, 
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
student_df
# Out:
#                Location   Name       School
# 0     1024 Billiard Ave   Jame     Business
# 1  Fraternity House #22   Mike          Law
# 2   512 Wilson Crescent  Sally  Engineering

# %%
pd.merge(staff_df, student_df, how="outer", left_on='Name', right_on='Name')
# Out:
#        Location_x   Name            Role            Location_y       School
# 0    State Street  Kelly  Director of HR                   NaN          NaN
# 1  Washington Ave  Sally  Course Liaison   512 Wilson Crescent  Engineering
# 2  Washington Ave  James          Grader                   NaN          NaN
# 3             NaN   Jame             NaN     1024 Billiard Ave     Business
# 4             NaN   Mike             NaN  Fraternity House #22          Law

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
(df.where(df['SUMLEV'] == 50).dropna().set_index(['STNAME', 'CTYNAME'])
 .rename(columns={'ESTIMATESBASE2010':'Estimate Base 2010'}))
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
import numpy as np
def min_max(row):
    data=row[['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 
              'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})
df.apply(min_max, axis=1)
# Out:
#           min      max
# 0     4785161  4858979
# 1       54660    55347
# 2      183193   203709
# 3       26489    27341
# 4       22512    22861
# 5       57373    57776
# 6       10606    10887
# 7       20154    20944
# 8      115620   118437
# 9       33993    34153
# 10      25859    26084
# 11      43665    43943
# 12      13170    13841
# 13      24675    25767
# 14      13456    13880
# 15      14921    15072
# 16      50177    51211
# 17      54354    54514
# 18      12662    13208
# 19      10724    11758
# 20      37796    38060
# 21      13853    13963
# 22      80374    82005
# 23      49501    50358
# 24      41131    43803
# 25      70869    71387
# 26      79465    81468
# 27      37784    38309
# 28     103057   104442
# 29      16759    17231
# ...       ...      ...
# 3163   131967   133674
# 3164   390076   396488
# 3165    51945    52422
# 3166    24033    24581
# 3167   167059   169639
# 3168    73435    74807
# 3169   564516   586107
# 3170    36428    37956
# ...

# %%
def min_max(row):
    data=row[['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 
              'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']]
    row['max']=np.max(data)
    row['min']=np.max(data)
    return row
df.apply(min_max, axis=1)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
rows=['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 
              'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']
df.apply(lambda x:np.max(x[rows]), axis=1)
# Out:
# 0       4858979
# 1         55347
# 2        203709
# 3         27341
# 4         22861
# 5         57776
# 6         10887
# 7         20944
# 8        118437
# 9         34153
# 10        26084
# 11        43943
# 12        13841
# 13        25767
# 14        13880
# 15        15072
# 16        51211
# 17        54514
# 18        13208
# 19        11758
# 20        38060
# 21        13963
# 22        82005
# 23        50358
# 24        43803
# 25        71387
# 26        81468
# 27        38309
# 28       104442
# 29        17231
#          ...
# 3163     133674
# 3164     396488
# 3165      52422
# 3166      24581
# 3167     169639
# 3168      74807
# 3169     586107
# 3170      37956
# 3171      12022
# 3172      49220
# 3173      15856
# 3174      14343
# 3175       7444
# 3176      41129
# 3177      13666
# 3178       4846
# 3179       8636
# 3180      97121
# 3181      18722
# 3182      82178
# 3183       2548
# 3184      29237
# 3185       8812
# 3186      30020
# ...

# %%
df['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
for state in df['STNAME'].unique():
    three = (sorted(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'], reverse=True)[:3])
    print (three)
# Out:
# [4779736.0, 658466.0, 412992.0]
# [710231.0, 291826.0, 97581.0]
# [6392017.0, 3817117.0, 980263.0]
# [2915918.0, 382748.0, 221339.0]
# [37253956.0, 9818605.0, 3095313.0]
# [5029196.0, 622263.0, 600158.0]
# [3574097.0, 916829.0, 894014.0]
# [897934.0, 538479.0, 197145.0]
# [601723.0, 601723.0]
# [18801310.0, 2496435.0, 1748066.0]
# [9687653.0, 920581.0, 805321.0]
# [1360301.0, 953207.0, 185079.0]
# [1567582.0, 392365.0, 188923.0]
# [12830632.0, 5194675.0, 916924.0]
# [6483802.0, 903393.0, 496005.0]
# [3046355.0, 430640.0, 211226.0]
# [2853118.0, 544179.0, 498365.0]
# [4339367.0, 741096.0, 295803.0]
# [4533372.0, 440171.0, 432552.0]
# [1328361.0, 281674.0, 197131.0]
# [5773552.0, 971777.0, 863420.0]
# [6547629.0, 1503085.0, 798552.0]
# [9883640.0, 1820584.0, 1202362.0]
# [5303925.0, 1152425.0, 508640.0]
# [2967297.0, 245285.0, 187105.0]
# [5988927.0, 998954.0, 674158.0]
# [989415.0, 147972.0, 109299.0]
# [1826341.0, 517110.0, 285407.0]
# [2700551.0, 1951269.0, 421407.0]
# ...

# %%
for group, frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 140580.4705882353
# Counties in state Alaska have an average population of 47348.73333333333
# Counties in state Arizona have an average population of 799002.125
# Counties in state Arkansas have an average population of 76734.68421052632
# Counties in state California have an average population of 1262845.9661016949
# Counties in state Colorado have an average population of 154744.4923076923
# Counties in state Connecticut have an average population of 794243.7777777778
# Counties in state Delaware have an average population of 448967.0
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 552979.7058823529
# Counties in state Georgia have an average population of 121095.6625
# Counties in state Hawaii have an average population of 453433.6666666667
# Counties in state Idaho have an average population of 69670.3111111111
# ...

# %%
df = df.set_index('STNAME')

# %%
def fun(item):
    if item[0] < 'M':
        return 0
    if item[0] < 'Q':
        return 1
    return 2
for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + 'records in group' + str(group) + 'for processing.')
# Out:
# There are 1196records in group0for processing.
# There are 1154records in group1for processing.
# There are 843records in group2for processing.

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#     STNAME  SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# 0  Alabama      40       3         6      1       0         Alabama
# 1  Alabama      50       3         6      1       1  Autauga County
# 2  Alabama      50       3         6      1       3  Baldwin County
# 3  Alabama      50       3         6      1       5  Barbour County
# 4  Alabama      50       3         6      1       7     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df = df.set_index('CTYNAME')

# %%
def fun(item):
    if item[0] < 'H':
        return 0
    if item[0] < 'P':
        return 1
    return 2
for group, frame in df.groupby(fun):
    print('There are '+ str(len(frame)) + 'records in group' + str(group) + 'for processing')
# Out:
# There are 1157records in group0for processing
# There are 1064records in group1for processing
# There are 972records in group2for processing

# %%
df = df.reset_index()

# %%
df=df[df['SUMLEV']==50]
df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010', 'POPESTIMATE2011']))
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>
# <class 'pandas.core.groupby.groupby.SeriesGroupBy'>

# %%
df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010', 'POPESTIMATE2011'].agg({'avg': np.average, 'sum':np.sum})
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                  avg                             sum  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                 71420.313433    71658.328358         4785161
# Alaska                  24621.413793    24921.379310          714021
# Arizona                427213.866667   431248.800000         6408208
# Arkansas                38965.253333    39180.506667         2922394
# California             643691.017241   650000.586207        37334079
# Colorado                78878.968750    79991.875000         5048254
# Connecticut            447464.625000   448719.875000         3579717
# Delaware               299930.333333   302638.666667          899791
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010', 'POPESTIMATE2011']
 .agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011':np.sum}))
# Out:
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# Connecticut             447464.625000          3589759
# Delaware                299930.333333           907916
# District of Columbia    605126.000000           620472
# Florida                 281341.641791         19105533
# Georgia                  61090.905660          9812280
# Hawaii                  272796.000000          1378227
# Idaho                    35704.227273          1584134
# Illinois                125894.598039         12861882
# Indiana                  70549.891304          6516845
# Iowa                     30815.090909          3065389
# ...

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D', 'D-'], index=['excellent', 
 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor', 'poor'])
df
# Out:
#             0
# excellent  A+
# excellent   A
# excellent  A-
# good       B+
# good        B
# good       B-
# ok         C+
# ok          C
# ok         C-
# poor       D+
# poor        D
# poor       D-

# %%
df.rename(columns={0:'Grades'}, inplace=True)

# %%
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D
# poor          D-

# %%
df['Grades'].astype('category').head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (12, object): [A, A+, A-, B, ..., C-, D, D+, D-]

# %%
grades = df['Grades'].astype('category', categories = ['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                            ordered=True)
grades
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D
# poor         NaN
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
grades > 'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\New folder\Launchcode\coursera dataScience\course1 week2\census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df = df[df['SUMLEV'] == 50]
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg': np.average})
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version

# %%
pd.cut(df['avg'], 10)
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# ...

# %%
s = pd.Series(['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Low'])

s.astype('category', categories=['Low', 'Medium', 'High'], ordered=True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0       Low
# 1       Low
# 2      High
# 3    Medium
# 4       Low
# 5      High
# 6       Low
# dtype: category
# Categories (3, object): [Low < Medium < High]
